# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_excel('mampala_data.xlsx')

# %%
data.head()
# Out:
#    observation   Age  Gender  years_experience qualification position  \
# 0             1   28    Male                 5        Degree   Junior
# 1             2   36    Male                 3        Degree      Mid
# 2             3   28    Male                 2       Diploma   Junior
# 3             4   25  Female                 1        Degree   Junior
# 4             5   34  Female                10        Degree      Mid
#
#        Department procurement_system_usage Internet_Reliability  \
# 0  HumanResources                     Good                 Good
# 1     Procurement                     Good                 Good
# 2        Accounts                     Good                 Good
# 3     Procurement             Satisfactory         Satisfactory
# 4     Procurement             Satisfactory         Satisfactory
#
#   Website_Purchase  ... E_Proccurement_Efficiency Reduces_Costs  \
# 0              Yes  ...                       Bad       Cheaper
# ...

# %%
# Function to create bar plots for categorical variables
def plot_bar(variable):
    plt.figure(figsize=(8, 5))
    sns.countplot(x=variable, data=data, palette='Set2')
    plt.title(f'Distribution of {variable}')
    plt.xticks(rotation=45)
    plt.show()

# List of categorical columns to visualiz 
categorical_columns =   ['procurement_system_usage','IT_integration_Supplier','Website_Purchase','Internet_Reliability', 
                       'E_Proccurement_Efficiency', 'Reduces_Costs', 
                       'approvals_workflow_after_eprocurement_adoption', 
                       'E_Procurement_Training', 'compatibility_with_the_existing_systems',
                       'Functionality_Eprocurement', 'Readily_Available', 'Work_Enhancement', 'Need_For_More_Training']

# Generate bar plots for all categorical columns
for col in categorical_columns:
    plot_bar(col)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\532420996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\532420996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\532420996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# ...

# %%
# List of categorical columns to visualiz 
categorical_columns =  ['IT_integration_Supplier','Need_For_More_Training','Business_Ease']

# Generate bar plots for all categorical columns
for col in categorical_columns:
    plot_bar(col)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4588\271424701.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_4588\271424701.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_4588\271424701.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to create and save bar plots for categorical variables
def plot_bar(variable):
    plt.figure(figsize=(8, 5))
    sns.countplot(x=variable, data=data, palette='Set2')
    plt.title(f'Distribution of {variable}')
    plt.xticks(rotation=45)
    
    # Save the plot as a JPG image
    filename = f"{variable}_distribution.jpg"
    plt.savefig(filename, format='jpg', dpi=300, bbox_inches='tight')
    
    plt.show()

# List of categorical columns to visualize
categorical_columns = [
    'IT_integration_Supplier','Need_For_More_Training','Business_Ease'
]

# Generate and save bar plots for all categorical columns
for col in categorical_columns:
    plot_bar(col)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\333545781.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\333545781.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')
# C:\Users\User\AppData\Local\Temp\ipykernel_15364\333545781.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=variable, data=data, palette='Set2')

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
# Step 1: Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head()
# Out:
#    observation   Age  Gender  years_experience qualification position  \
# 0             1   28    Male                 5        Degree   Junior
# 1             2   36    Male                 3        Degree      Mid
# 2             3   28    Male                 2       Diploma   Junior
# 3             4   25  Female                 1        Degree   Junior
# 4             5   34  Female                10        Degree      Mid
#
#        Department procurement_system_usage Internet_Reliability  \
# 0  HumanResources                     Good                 Good
# 1     Procurement                     Good                 Good
# 2        Accounts                     Good                 Good
# 3     Procurement             Satisfactory         Satisfactory
# 4     Environment             Satisfactory         Satisfactory
#
#   Website_Purchase  ... E_Proccurement_Efficiency Reduces_Costs  \
# 0              Yes  ...                       Bad       Cheaper
# ...

# %%
data.columns
# Out:
# Index(['observation ', 'Age', 'Gender', 'years_experience', 'qualification',
#        'position', 'Department', 'procurement_system_usage',
#        'Internet_Reliability', 'Website_Purchase',
#        'orders_on_special_electronic_marketplaces ', 'IT_integration_Supplier',
#        'E_Proccurement_Efficiency', 'Reduces_Costs',
#        'approvals_workflow_after_eprocurement_adoption',
#        'E_Procurement_Training', 'compatibility_with_the_existing_systems',
#        'Functionality_Eprocurement', 'Readily_Available', 'Work_Enhancement',
#        'Need_For_More_Training', 'Business_Ease'],
#       dtype='object')

# %% [markdown]
# ## STACKED GRAPHS

# %%
from scipy.stats import chi2_contingency

# Chi-square test on two categorical columns (Procurement Usage vs. E_Proccurement_Efficiency)
contingency_table = pd.crosstab(data['procurement_system_usage'], data['E_Proccurement_Efficiency'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi2 Statistic: {chi2}, p-value: {p}")
# Out:
# Chi2 Statistic: 4.139202325452325, p-value: 0.844350712314276

# %%
data.columns
# Out:
# Index(['observation ', 'Age', 'Gender', 'years_experience', 'qualification',
#        'position', 'Department', 'procurement_system_usage',
#        'Internet_Reliability', 'Website_Purchase',
#        'orders_on_special_electronic_marketplaces ', 'IT_integration_Supplier',
#        'E_Proccurement_Efficiency', 'Reduces_Costs',
#        'approvals_workflow_after_eprocurement_adoption',
#        'E_Procurement_Training', 'compatibility_with_the_existing_systems',
#        'Functionality_Eprocurement', 'Readily_Available', 'Work_Enhancement',
#        'Need_For_More_Training', 'Business_Ease'],
#       dtype='object')

# %%
# Example: Group by 'Department' and 'Adoption_Level', then create a stacked bar chart
if 'Department' in data.columns and 'Business_Ease' in data.columns:
    grouped_data = data.groupby(['Department', 'Business_Ease']).size().unstack()

    # Plotting the stacked bar chart
    plt.figure(figsize=(10, 6))
    grouped_data.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))

    plt.title('EASE OF DOING BUSINESS')
    plt.xlabel('Department')
    plt.ylabel('Count')
    plt.legend(title='Ease of doing business'), 
    plt.tight_layout()

    # Save the graph as an image
    plt.savefig('stacked_bar_graph.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# Example: Group by 'Years_of_Experience' and 'E_Proccurement_Efficiency'
if 'Years_of_Experience' in df.columns and 'E_Proccurement_Efficiency' in df.columns:
    grouped_data_2 = df.groupby(['Years_of_Experience', 'E_Proccurement_Efficiency']).size().unstack()

    # Plotting another stacked bar chart
    plt.figure(figsize=(10, 6))
    grouped_data_2.plot(kind='bar', stacked=True, colormap='plasma', figsize=(10, 6))

    plt.title('E-Procurement Efficiency by Years of Experience')
    plt.xlabel('Years of Experience')
    plt.ylabel('Count')
    plt.legend(title='E-Procurement Efficiency', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Save the graph as an image
    plt.savefig('stacked_bar_graph_efficiency.png', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Example: Group by 'Years_of_Experience' and 'E_Proccurement_Efficiency'
# ----> 2 if 'Years_of_Experience' in df.columns and 'E_Proccurement_Efficiency' in df.columns:
#       3     grouped_data_2 = df.groupby(['Years_of_Experience', 'E_Proccurement_Efficiency']).size().unstack()
#       5     # Plotting another stacked bar chart
#
# NameError: name 'df' is not defined

# %%
# Example: Group by 'Department' and 'Adoption_Level', then create a stacked bar chart
if 'Department' in data.columns and '' in data.columns:
    grouped_data = data.groupby(['Department', 'Reduces_Costs']).size().unstack()

    # Plotting the stacked bar chart
    plt.figure(figsize=(10, 6))
    grouped_data.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))

    plt.title('Cost Reduction By Department')
    plt.xlabel('Employment Grade')
    plt.ylabel('Count')
    plt.legend(title='Cost'), 
    plt.tight_layout()

    # Save the graph as an image
    plt.savefig('stacked_bar_graph.png', dpi=300, bbox_inches='tight')
    plt.show()
